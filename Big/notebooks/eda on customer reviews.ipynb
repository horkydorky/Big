# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\adhik\OneDrive\Desktop\Business_insights generator\Big\data\raw\customer_Reviews.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# ...

# %%
df.isna().sum()/len(df)*100
# Out:
# id                      0.00
# dateAdded               0.00
# dateUpdated             0.00
# name                    0.00
# asins                   0.00
# brand                   0.00
# categories              0.00
# primaryCategories       0.00
# imageURLs               0.00
# keys                    0.00
# manufacturer            0.00
# manufacturerNumber      0.00
# reviews.date            0.00
# reviews.dateAdded      78.96
# reviews.dateSeen        0.00
# reviews.doRecommend     0.00
# reviews.id             99.42
# reviews.numHelpful      0.00
# reviews.rating          0.00
# reviews.sourceURLs      0.00
# reviews.text            0.00
# reviews.title           0.26
# reviews.username        0.02
# sourceURLs              0.00
# dtype: float64

# %%
columns_to_keep = [
    'asins',
    'reviews.rating',
    'reviews.title',
    'reviews.text'
]

# %%
df_reviews_clean = df[columns_to_keep].copy()

print("Created a new, simplified DataFrame with essential columns.")
# Out:
# Created a new, simplified DataFrame with essential columns.

# %%
df_reviews_clean.isna().sum()
# Out:
# asins              0
# reviews.rating     0
# reviews.title     13
# reviews.text       0
# dtype: int64

# %%
df_reviews_clean.dropna(inplace=True)

# %%
df_reviews_clean.isna().sum()
# Out:
# asins             0
# reviews.rating    0
# reviews.title     0
# reviews.text      0
# dtype: int64
